# %%
import glob

# %%
source = 'cf252'
base = '/hdfs/user/ak18773/od_simulations/BACCARAT_6.2.11_DER_9.1.0_LZAP_5.2.8/' + source + '/lzap_output/'

# %%
files = glob.glob(base + '*mctruth.root')

# %%
for f in files:
    print(f)
# Out:
# /hdfs/user/ak18773/od_simulations/BACCARAT_6.2.11_DER_9.1.0_LZAP_5.2.8/cf252/lzap_output/LZAP_SEED100_mctruth.root
# /hdfs/user/ak18773/od_simulations/BACCARAT_6.2.11_DER_9.1.0_LZAP_5.2.8/cf252/lzap_output/LZAP_SEED102_mctruth.root
# /hdfs/user/ak18773/od_simulations/BACCARAT_6.2.11_DER_9.1.0_LZAP_5.2.8/cf252/lzap_output/LZAP_SEED104_mctruth.root
# /hdfs/user/ak18773/od_simulations/BACCARAT_6.2.11_DER_9.1.0_LZAP_5.2.8/cf252/lzap_output/LZAP_SEED106_mctruth.root
# /hdfs/user/ak18773/od_simulations/BACCARAT_6.2.11_DER_9.1.0_LZAP_5.2.8/cf252/lzap_output/LZAP_SEED108_mctruth.root
# /hdfs/user/ak18773/od_simulations/BACCARAT_6.2.11_DER_9.1.0_LZAP_5.2.8/cf252/lzap_output/LZAP_SEED110_mctruth.root
# /hdfs/user/ak18773/od_simulations/BACCARAT_6.2.11_DER_9.1.0_LZAP_5.2.8/cf252/lzap_output/LZAP_SEED112_mctruth.root
# /hdfs/user/ak18773/od_simulations/BACCARAT_6.2.11_DER_9.1.0_LZAP_5.2.8/cf252/lzap_output/LZAP_SEED114_mctruth.root
# ...

# %%
f = glob.glob('/hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/*mctruth*')

# %%
for q in f:
    print(q)
# Out:
# /hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/LZAP_SEED100_mctruth.root
# /hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/LZAP_SEED101_mctruth.root
# /hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/LZAP_SEED102_mctruth.root
# /hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/LZAP_SEED103_mctruth.root
# /hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/LZAP_SEED104_mctruth.root
# /hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/LZAP_SEED105_mctruth.root
# /hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/LZAP_SEED106_mctruth.root
# /hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/LZAP_SEED107_mctruth.root
# /hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/LZAP_SEED108_mctruth.root
# /hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/LZAP_SEED109_mctruth.root
# /hdfs/user/ak18773/od_likelihood/pure_rockgamma/lzap_output/LZAP_SEED110_mctruth.root
# ...
